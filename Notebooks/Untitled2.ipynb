# %%
# Install the latest release of Haystack in your own environment
#! pip install farm-haystack

# Install the latest master of Haystack
# !pip install --user git+https://github.com/deepset-ai/haystack.git#egg=farm-haystack[colab,ocr]
# Out:
# Collecting farm-haystack[colab,ocr]
#   Cloning https://github.com/deepset-ai/haystack.git to c:\users\alien\appdata\local\temp\pip-install-f3ldrkyw\farm-haystack_9bb2ddbbd0204053b2645489b2c60960
#   Resolved https://github.com/deepset-ai/haystack.git to commit 1e01cd0efb20d98905c84461e0433d5db4084b7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting posthog
#   Using cached posthog-1.4.9-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: more-itertools in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (8.10.0)
# Requirement already satisfied: scipy>=1.3.2 in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (1.7.1)
# Collecting azure-ai-formrecognizer==3.2.0b2
#   Using cached azure_ai_formrecognizer-3.2.0b2-py2.py3-none-any.whl (219 kB)
# Collecting pydantic
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting elastic-apm
#   Using cached elastic_apm-6.10.1-cp39-cp39-win_amd64.whl
# Collecting transformers==4.20.1
#   Using cached transformers-4.20.1-py3-none-any.whl (4.4 MB)
# Collecting python-docx
#   Using cached python_docx-0.8.11-py3-none-any.whl
# Collecting mlflow
#   Using cached mlflow-1.27.0-py3-none-any.whl (17.9 MB)
# Collecting azure-core<1.23
#   Using cached azure_core-1.22.1-py3-none-any.whl (178 kB)
# Collecting dill
#   Using cached dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting elasticsearch<7.11,>=7.7
#   Using cached elasticsearch-7.10.1-py2.py3-none-any.whl (322 kB)
# Collecting quantulum3
#   Using cached quantulum3-0.7.10-py3-none-any.whl (10.7 MB)
# Requirement already satisfied: requests in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (2.26.0)
# Requirement already satisfied: pandas in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (1.3.4)
# Requirement already satisfied: torch<1.12,>1.9 in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (1.11.0)
# Requirement already satisfied: jsonschema in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (3.2.0)
# Requirement already satisfied: nltk in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (3.6.5)
# Collecting seqeval
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Collecting rapidfuzz==2.0.13
#   Using cached rapidfuzz-2.0.13-cp39-cp39-win_amd64.whl (1.0 MB)
# Requirement already satisfied: networkx in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (2.6.3)
# Collecting mmh3
#   Using cached mmh3-3.0.0-cp39-cp39-win_amd64.whl (15 kB)
# Collecting sentence-transformers>=2.2.0
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Collecting scikit-learn>=1.0.0
#   Using cached scikit_learn-1.1.1-cp39-cp39-win_amd64.whl (7.4 MB)
# Collecting tika
#   Using cached tika-1.24-py3-none-any.whl
# Requirement already satisfied: tqdm in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (4.62.3)
# Collecting langdetect
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Requirement already satisfied: pillow in f:\anaconda3\lib\site-packages (from farm-haystack[colab,ocr]) (8.4.0)
# Collecting pdf2image==1.14.0
#   Using cached pdf2image-1.14.0-py3-none-any.whl (10 kB)
# Collecting pytesseract==0.3.7
#   Using cached pytesseract-0.3.7-py2.py3-none-any.whl
# Collecting grpcio==1.43.0
#   Using cached grpcio-1.43.0-cp39-cp39-win_amd64.whl (3.4 MB)
# Collecting msrest>=0.6.21
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Requirement already satisfied: six>=1.11.0 in f:\anaconda3\lib\site-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack[colab,ocr]) (1.16.0)
# Collecting azure-common~=1.1
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting jarowinkler<1.1.0,>=1.0.3
#   Using cached jarowinkler-1.0.5-cp39-cp39-win_amd64.whl (59 kB)
# Requirement already satisfied: pyyaml>=5.1 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack[colab,ocr]) (6.0)
# Requirement already satisfied: numpy>=1.17 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack[colab,ocr]) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack[colab,ocr]) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack[colab,ocr]) (2021.8.3)
# Requirement already satisfied: filelock in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack[colab,ocr]) (3.3.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack[colab,ocr]) (0.12.1)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Using cached huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
# Requirement already satisfied: urllib3<2,>=1.21.1 in f:\anaconda3\lib\site-packages (from elasticsearch<7.11,>=7.7->farm-haystack[colab,ocr]) (1.26.7)
# Requirement already satisfied: certifi in f:\anaconda3\lib\site-packages (from elasticsearch<7.11,>=7.7->farm-haystack[colab,ocr]) (2021.10.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in f:\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.1->farm-haystack[colab,ocr]) (3.10.0.2)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting msrest>=0.6.21
#   Using cached msrest-0.7.0-py2.py3-none-any.whl (85 kB)
#   Using cached msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in f:\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[colab,ocr]) (1.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in f:\anaconda3\lib\site-packages (from packaging>=20.0->transformers==4.20.1->farm-haystack[colab,ocr]) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda3\lib\site-packages (from requests->farm-haystack[colab,ocr]) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in f:\anaconda3\lib\site-packages (from requests->farm-haystack[colab,ocr]) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in f:\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[colab,ocr]) (3.2.0)
# Requirement already satisfied: joblib>=1.0.0 in f:\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->farm-haystack[colab,ocr]) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->farm-haystack[colab,ocr]) (2.2.0)
# Collecting torchvision
#   Using cached torchvision-0.13.0-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: colorama in f:\anaconda3\lib\site-packages (from tqdm->farm-haystack[colab,ocr]) (0.4.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in f:\anaconda3\lib\site-packages (from jsonschema->farm-haystack[colab,ocr]) (0.18.0)
# Requirement already satisfied: setuptools in f:\anaconda3\lib\site-packages (from jsonschema->farm-haystack[colab,ocr]) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in f:\anaconda3\lib\site-packages (from jsonschema->farm-haystack[colab,ocr]) (21.2.0)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: click>=7.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (8.0.3)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.17.0-py3-none-any.whl
# Requirement already satisfied: Flask in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (1.1.2)
# Collecting alembic
#   Using cached alembic-1.8.0-py3-none-any.whl (209 kB)
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: protobuf>=3.12.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (3.20.0)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Requirement already satisfied: cloudpickle in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (2.0.0)
# Collecting waitress
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (4.8.1)
# Requirement already satisfied: sqlalchemy>=1.4.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (1.4.22)
# Requirement already satisfied: pytz in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (2021.3)
# Requirement already satisfied: entrypoints in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack[colab,ocr]) (0.3)
# Requirement already satisfied: tabulate>=0.7.7 in f:\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->farm-haystack[colab,ocr]) (0.8.10)
# Requirement already satisfied: pyjwt>=1.7.0 in f:\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->farm-haystack[colab,ocr]) (2.1.0)
# Collecting pywin32==227
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in f:\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->farm-haystack[colab,ocr]) (1.3.3)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in f:\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->farm-haystack[colab,ocr]) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in f:\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->farm-haystack[colab,ocr]) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\anaconda3\lib\site-packages (from sqlalchemy>=1.4.0->mlflow->farm-haystack[colab,ocr]) (1.1.1)
# Collecting Mako
#   Using cached Mako-1.2.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: Werkzeug>=0.15 in f:\anaconda3\lib\site-packages (from Flask->mlflow->farm-haystack[colab,ocr]) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in f:\anaconda3\lib\site-packages (from Flask->mlflow->farm-haystack[colab,ocr]) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in f:\anaconda3\lib\site-packages (from Flask->mlflow->farm-haystack[colab,ocr]) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in f:\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->mlflow->farm-haystack[colab,ocr]) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in f:\anaconda3\lib\site-packages (from pandas->farm-haystack[colab,ocr]) (2.8.2)
# Collecting backoff<2.0.0,>=1.10.0
#   Using cached backoff-1.11.1-py2.py3-none-any.whl (13 kB)
# Collecting monotonic>=1.5
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: prometheus-client in f:\anaconda3\lib\site-packages (from prometheus-flask-exporter->mlflow->farm-haystack[colab,ocr]) (0.11.0)
# Requirement already satisfied: lxml>=2.3.2 in f:\anaconda3\lib\site-packages (from python-docx->farm-haystack[colab,ocr]) (4.6.3)
# Collecting inflect
#   Using cached inflect-5.6.0-py3-none-any.whl (33 kB)
# Collecting num2words
#   Using cached num2words-0.5.10-py3-none-any.whl (101 kB)
# Collecting docopt>=0.6.2
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting torchvision
#   Using cached torchvision-0.12.0-cp39-cp39-win_amd64.whl (1.0 MB)
# Building wheels for collected packages: farm-haystack
#   Building wheel for farm-haystack (PEP 517): started
#   Building wheel for farm-haystack (PEP 517): finished with status 'done'
#   Created wheel for farm-haystack: filename=farm_haystack-1.5.1rc0-py3-none-any.whl size=588947 sha256=02105c618fbe54b396b7559419b399f391d21ad22fb3f5f665eef9f1730584b5
#   Stored in directory: C:\Users\Alien\AppData\Local\Temp\pip-ephem-wheel-cache-kff1ik1j\wheels\47\fc\da\022dd81c208ff5db06a026f418c7060d75bda1eee7760fc577
# Successfully built farm-haystack
# Installing collected packages: pywin32, Mako, isodate, huggingface-hub, gitdb, docopt, waitress, transformers, torchvision, sqlparse, sentencepiece, scikit-learn, querystring-parser, prometheus-flask-exporter, num2words, msrest, monotonic, jarowinkler, inflect, gitpython, docker, databricks-cli, backoff, azure-core, azure-common, alembic, tika, seqeval, sentence-transformers, rapidfuzz, quantulum3, python-docx, pydantic, posthog, mmh3, mlflow, langdetect, elasticsearch, elastic-apm, dill, azure-ai-formrecognizer, pytesseract, pdf2image, grpcio, farm-haystack
# Successfully installed Mako-1.2.1 alembic-1.8.0 azure-ai-formrecognizer-3.2.0b2 azure-common-1.1.28 azure-core-1.22.1 backoff-1.11.1 databricks-cli-0.17.0 dill-0.3.5.1 docker-5.0.3 docopt-0.6.2 elastic-apm-6.10.1 elasticsearch-7.10.1 farm-haystack-1.5.1rc0 gitdb-4.0.9 gitpython-3.1.27 grpcio-1.43.0 huggingface-hub-0.8.1 inflect-5.6.0 isodate-0.6.1 jarowinkler-1.0.5 langdetect-1.0.9 mlflow-1.27.0 mmh3-3.0.0 monotonic-1.6 msrest-0.6.21 num2words-0.5.10 pdf2image-1.14.0 posthog-1.4.9 prometheus-flask-exporter-0.20.2 pydantic-1.9.1 pytesseract-0.3.7 python-docx-0.8.11 pywin32-227 quantulum3-0.7.10 querystring-parser-1.2.4 rapidfuzz-2.0.13 scikit-learn-1.1.1 sentence-transformers-2.2.2 sentencepiece-0.1.96 seqeval-1.2.2 sqlparse-0.4.2 tika-1.24 torchvision-0.12.0 transformers-4.20.1 waitress-2.1.2
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
#   Running command git clone -q https://github.com/deepset-ai/haystack.git 'C:\Users\Alien\AppData\Local\Temp\pip-install-f3ldrkyw\farm-haystack_9bb2ddbbd0204053b2645489b2c60960'
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
#   WARNING: The script mako-render.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script waitress-serve.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts databricks.exe and dbfs.exe are installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tika-python.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts mlflow.exe and mlp.exe are installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pytesseract.exe is installed in 'C:\Users\Alien\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)

# %%
pip install farm-haystack
# Out:
# Requirement already satisfied: farm-haystack in c:\users\alien\appdata\roaming\python\python39\site-packages (1.5.1rc0)
# Requirement already satisfied: azure-ai-formrecognizer==3.2.0b2 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (3.2.0b2)
# Requirement already satisfied: posthog in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.4.9)
# Requirement already satisfied: mlflow in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.27.0)
# Requirement already satisfied: rapidfuzz==2.0.13 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (2.0.13)
# Requirement already satisfied: jsonschema in f:\anaconda3\lib\site-packages (from farm-haystack) (3.2.0)
# Requirement already satisfied: python-docx in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (0.8.11)
# Requirement already satisfied: quantulum3 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (0.7.10)
# Requirement already satisfied: tqdm in f:\anaconda3\lib\site-packages (from farm-haystack) (4.62.3)
# Requirement already satisfied: pandas in f:\anaconda3\lib\site-packages (from farm-haystack) (1.3.4)
# Requirement already satisfied: transformers==4.20.1 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (4.20.1)
# Requirement already satisfied: more-itertools in f:\anaconda3\lib\site-packages (from farm-haystack) (8.10.0)
# Requirement already satisfied: torch<1.12,>1.9 in f:\anaconda3\lib\site-packages (from farm-haystack) (1.11.0)
# Requirement already satisfied: mmh3 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (3.0.0)
# Requirement already satisfied: sentence-transformers>=2.2.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (2.2.2)
# Requirement already satisfied: elastic-apm in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (6.10.1)
# Requirement already satisfied: requests in f:\anaconda3\lib\site-packages (from farm-haystack) (2.26.0)
# Requirement already satisfied: pydantic in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.9.1)
# Requirement already satisfied: networkx in f:\anaconda3\lib\site-packages (from farm-haystack) (2.6.3)
# Requirement already satisfied: tika in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.24)
# Requirement already satisfied: azure-core<1.23 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.22.1)
# Requirement already satisfied: nltk in f:\anaconda3\lib\site-packages (from farm-haystack) (3.6.5)
# Requirement already satisfied: seqeval in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.2.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.1.1)
# Requirement already satisfied: dill in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (0.3.5.1)
# Requirement already satisfied: scipy>=1.3.2 in f:\anaconda3\lib\site-packages (from farm-haystack) (1.7.1)
# Requirement already satisfied: elasticsearch<7.11,>=7.7 in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (7.10.1)
# Requirement already satisfied: langdetect in c:\users\alien\appdata\roaming\python\python39\site-packages (from farm-haystack) (1.0.9)
# Requirement already satisfied: msrest>=0.6.21 in c:\users\alien\appdata\roaming\python\python39\site-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack) (0.6.21)
# Requirement already satisfied: azure-common~=1.1 in c:\users\alien\appdata\roaming\python\python39\site-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack) (1.1.28)
# Requirement already satisfied: six>=1.11.0 in f:\anaconda3\lib\site-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack) (1.16.0)
# Requirement already satisfied: jarowinkler<1.1.0,>=1.0.3 in c:\users\alien\appdata\roaming\python\python39\site-packages (from rapidfuzz==2.0.13->farm-haystack) (1.0.5)
# Requirement already satisfied: filelock in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack) (3.3.1)
# Requirement already satisfied: numpy>=1.17 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack) (1.20.3)
# Requirement already satisfied: pyyaml>=5.1 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack) (0.12.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from transformers==4.20.1->farm-haystack) (0.8.1)
# Requirement already satisfied: regex!=2019.12.17 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack) (2021.8.3)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda3\lib\site-packages (from transformers==4.20.1->farm-haystack) (21.0)
# Requirement already satisfied: urllib3<2,>=1.21.1 in f:\anaconda3\lib\site-packages (from elasticsearch<7.11,>=7.7->farm-haystack) (1.26.7)
# Requirement already satisfied: certifi in f:\anaconda3\lib\site-packages (from elasticsearch<7.11,>=7.7->farm-haystack) (2021.10.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in f:\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.1->farm-haystack) (3.10.0.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in f:\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack) (1.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in f:\anaconda3\lib\site-packages (from packaging>=20.0->transformers==4.20.1->farm-haystack) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in f:\anaconda3\lib\site-packages (from requests->farm-haystack) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda3\lib\site-packages (from requests->farm-haystack) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in f:\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->farm-haystack) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in f:\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->farm-haystack) (1.1.0)
# Requirement already satisfied: torchvision in c:\users\alien\appdata\roaming\python\python39\site-packages (from sentence-transformers>=2.2.0->farm-haystack) (0.12.0)
# Requirement already satisfied: sentencepiece in c:\users\alien\appdata\roaming\python\python39\site-packages (from sentence-transformers>=2.2.0->farm-haystack) (0.1.96)
# Requirement already satisfied: colorama in f:\anaconda3\lib\site-packages (from tqdm->farm-haystack) (0.4.4)
# Requirement already satisfied: attrs>=17.4.0 in f:\anaconda3\lib\site-packages (from jsonschema->farm-haystack) (21.2.0)
# Requirement already satisfied: setuptools in f:\anaconda3\lib\site-packages (from jsonschema->farm-haystack) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in f:\anaconda3\lib\site-packages (from jsonschema->farm-haystack) (0.18.0)
# Requirement already satisfied: pytz in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (2021.3)
# Requirement already satisfied: alembic in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (1.8.0)
# Requirement already satisfied: prometheus-flask-exporter in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (0.20.2)
# Requirement already satisfied: sqlalchemy>=1.4.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (1.4.22)
# Requirement already satisfied: databricks-cli>=0.8.7 in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (0.17.0)
# Requirement already satisfied: docker>=4.0.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (5.0.3)
# Requirement already satisfied: cloudpickle in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (2.0.0)
# Requirement already satisfied: querystring-parser in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (1.2.4)
# Requirement already satisfied: protobuf>=3.12.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (3.20.0)
# Requirement already satisfied: gitpython>=2.1.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (3.1.27)
# Requirement already satisfied: waitress in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (2.1.2)
# Requirement already satisfied: click>=7.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (8.0.3)
# Requirement already satisfied: Flask in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (1.1.2)
# Requirement already satisfied: entrypoints in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (0.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in f:\anaconda3\lib\site-packages (from mlflow->farm-haystack) (4.8.1)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\alien\appdata\roaming\python\python39\site-packages (from mlflow->farm-haystack) (0.4.2)
# Requirement already satisfied: tabulate>=0.7.7 in f:\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->farm-haystack) (0.8.10)
# Requirement already satisfied: pyjwt>=1.7.0 in f:\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->farm-haystack) (2.1.0)
# Requirement already satisfied: websocket-client>=0.32.0 in f:\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->farm-haystack) (1.3.3)
# Requirement already satisfied: pywin32==227 in c:\users\alien\appdata\roaming\python\python39\site-packages (from docker>=4.0.0->mlflow->farm-haystack) (227)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\alien\appdata\roaming\python\python39\site-packages (from gitpython>=2.1.0->mlflow->farm-haystack) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in f:\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->farm-haystack) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in f:\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->farm-haystack) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\anaconda3\lib\site-packages (from sqlalchemy>=1.4.0->mlflow->farm-haystack) (1.1.1)
# Requirement already satisfied: Mako in c:\users\alien\appdata\roaming\python\python39\site-packages (from alembic->mlflow->farm-haystack) (1.2.1)
# Requirement already satisfied: Jinja2>=2.10.1 in f:\anaconda3\lib\site-packages (from Flask->mlflow->farm-haystack) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in f:\anaconda3\lib\site-packages (from Flask->mlflow->farm-haystack) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in f:\anaconda3\lib\site-packages (from Flask->mlflow->farm-haystack) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in f:\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->mlflow->farm-haystack) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in f:\anaconda3\lib\site-packages (from pandas->farm-haystack) (2.8.2)
# Requirement already satisfied: monotonic>=1.5 in c:\users\alien\appdata\roaming\python\python39\site-packages (from posthog->farm-haystack) (1.6)
# Requirement already satisfied: backoff<2.0.0,>=1.10.0 in c:\users\alien\appdata\roaming\python\python39\site-packages (from posthog->farm-haystack) (1.11.1)
# Requirement already satisfied: prometheus-client in f:\anaconda3\lib\site-packages (from prometheus-flask-exporter->mlflow->farm-haystack) (0.11.0)
# Requirement already satisfied: lxml>=2.3.2 in f:\anaconda3\lib\site-packages (from python-docx->farm-haystack) (4.6.3)
# Requirement already satisfied: inflect in c:\users\alien\appdata\roaming\python\python39\site-packages (from quantulum3->farm-haystack) (5.6.0)
# Requirement already satisfied: num2words in c:\users\alien\appdata\roaming\python\python39\site-packages (from quantulum3->farm-haystack) (0.5.10)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\alien\appdata\roaming\python\python39\site-packages (from num2words->quantulum3->farm-haystack) (0.6.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in f:\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=2.2.0->farm-haystack) (8.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)

# %%
pip install 'farm-haystack[faiss]'
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# ERROR: Invalid requirement: "'farm-haystack[faiss]'"
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (f:\anaconda3\lib\site-packages)

# %%
from haystack.nodes import PDFToTextConverter
from haystack.preprocessor import PreProcessor
from haystack.document_stores.faiss import FAISSDocumentStore
from haystack.retriever import DensePassageRetriever
from haystack.reader import FARMReader
from haystack.pipeline import ExtractiveQAPipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8900/1765921497.py in <module>
# ----> 1 from haystack.nodes import PDFToTextConverter
#       2 from haystack.preprocessor import PreProcessor
#       3 from haystack.document_stores.faiss import FAISSDocumentStore
#       4 from haystack.retriever import DensePassageRetriever
#       5 from haystack.reader import FARMReader
#
# ModuleNotFoundError: No module named 'haystack.nodes'

# %%
import haystack

# %%
haystack
# Out:
# <module 'haystack' (namespace)>

# %%
from haystack.utils import launch_es
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8900/3060506705.py in <module>
# ----> 1 from haystack.utils import launch_es
#
# ModuleNotFoundError: No module named 'haystack.utils'
